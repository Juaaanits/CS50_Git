# %% [markdown]
# <a href="https://colab.research.google.com/github/Juaaanits/CS50_Git/blob/main/Essential_Math_for_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Chapter 1. Basic Math and
# Calculus Review**

# %% [markdown]
# PEMDAS

# %%
x = 2 * ((3 + 2)**2 / 5) - 4
print(x)
# Out:
# 6.0

# %% [markdown]
# Variables

# %%
x = int(input("Enter a number: "))
y = 3 * x
print(y)
# Out:
# Enter a number: 3
# 9

# %% [markdown]
# Greek variable names in Python

# %%
beta = 1.75
theta = 30.0

# %% [markdown]
# Linear Function using Python

# %%
def f(x):
  return (2*x)+1

x_values = [0, 1, 2, 3, 4, 5]

for x in x_values:
  y = f(x)
  print(y)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %% [markdown]
# Charting a linear function in Python using SymPy

# %%
from sympy import*

# %% [markdown]
# y = 2x + 1

# %%
x = symbols('x')
f = (2*x)+1
plot(f)

# %% [markdown]
# y = 3x - 2

# %%
x = symbols('x')
y = 3*x-2
plot(y)

# %% [markdown]
# Charting an exponential function

# %% [markdown]
# f(x) = x^2 + 1

# %%
x = symbols('x')
y = x**2 + 1
plot(y)

# %% [markdown]
# Functions with Multiple Input Variables

# %%
from sympy import*
from sympy.plotting import plot3d

# %% [markdown]
# f(x, y) = 2x + 3y

# %%
x, y = symbols('x y')
#y = symbols('y')
f = 2*x + 3*y
plot3d(f)

# %% [markdown]
# Summation

# %% [markdown]
# ![Screenshot 2023-08-02 171203.png](data:image/png;base64,...)

# %%
summation = sum(2 * i for i in range (1,6))
print(summation)
# Out:
# 30

# %% [markdown]
# ![Screenshot 2023-08-02 204017.png](data:image/png;base64,...)

# %%
x = [1, 4, 6, 2]
n = len(x)

summation = sum(10*x[i] for i in range(0, n))
print(summation)
# Out:
# 130

# %%
from sympy import *
i,n = symbols('i n')
# iterate each element i from 1 to n,
# then multiply and sum
summation = Sum(2*i,(i,1,n))
# specify n as 5,
# iterating the numbers 1 through 5
up_to_5 = summation.subs(n, 5)
print(up_to_5.doit()) # 30
# Out:
# 30

# %% [markdown]
# **SOLUTION**\
# Starting from 1 up to 5
#
# *  2 * 1 = 2
# *  2 * 2 = 4
# *  2 * 3 = 6
# *  2 * 4 = 8
# *  2 * 5 = 10
# *  Total = 30

# %% [markdown]
# Exponents

# %%
x = symbols('x')
expr = x**2/x**5
print(expr)
# Out:
# x**(-3)

# %% [markdown]
# Logarithm

# %%
from math import log

# %% [markdown]
# ![Screenshot 2023-08-02 211854.png](data:image/png;base64,...)

# %%
x = log(8, 2)
print(x)
# Out:
# 3

# %% [markdown]
# ![Screenshot 2023-08-02 212818.png](data:image/png;base64,...)

# %% [markdown]
# Euler’s Number and Natural Logarithms

# %% [markdown]
# *Compound Interest Formula*
# ![Screenshot 2023-08-04 075848.png](data:image/png;base64,...)
# ![Screenshot 2023-08-04 080204.png](data:image/png;base64,...)

# %%
from math import exp

# %%
p = 100
r = .20
n = 12
t = 2.0

a = p * (1+(r/n))**(n*t)
print(a)
# Out:
# 148.69146179463576

# %% [markdown]
# ![Screenshot 2023-08-04 080411.png](data:image/png;base64,...)

# %%
p = 100
r = .20
t = 2.0

a = p * exp(r * t)
print(a)
# Out:
# 149.18246976412703

# %%
from math import log

# %%
x = log(10)
print(x)
# Out:
# 2.302585092994046

# %% [markdown]
# Limits

# %%
from sympy import *

# %% [markdown]
# ![Screenshot 2023-08-04 081005.png](data:image/png;base64,...)

# %%
x = symbols('x')
f = 1 / x
result = limit(f, x, oo)

print(result)
# Out:
# 0

# %% [markdown]
# ![Screenshot 2023-08-04 081027.png](data:image/png;base64,...)

# %%
n = symbols('n')
f = (1 + (1 / n)) ** n
result = limit(f, n, oo)

print(result)
print(result.evalf())
# Out:
# E
# 2.71828182845905

# %% [markdown]
# Derivative

# %%
def derivative_x(f, x,  step_size):
  m = (f(x + step_size) - f(x)) / ((x + step_size) - x)
  return m

def my_function(x):
  return x**2

slope_at_2 = derivative_x(my_function, 2, 0.00001)
print(slope_at_2)
# Out:
# 4.000010000000827

# %%
from sympy import *

#declare variable
x = symbols('x')

#declare function
f = x ** 2

#Get the derivative
dx_f = diff(f)
print(dx_f)
# Out:
# 2*x

# %%
def dx_f(x):
  return 2*x

slope_at_2 = dx_f(2.0)

print(slope_at_2)
# Out:
# 4.0

# %% [markdown]
# Partial Derivatives

# %%
from sympy import *
from sympy.plotting import plot3d

# %%
#Declare variables
x, y = symbols('x y')

#Declare function
f = 2*x**3 + 3*y**3

#Calculate partial derivatives
dx_f = diff(f, x)
dy_f = diff(f, y)

print(dx_f)
print(dy_f)

plot3d(f)
# Out:
# 6*x**2
# 9*y**2

# %% [markdown]
# Using Limits to Calculate Derivatives

# %% [markdown]
# ![Screenshot 2023-08-06 142808.png](data:image/png;base64,...)

# %%
from sympy import *

# %%
# "x" and step size "s"
x, s = symbols('x s')

#declare function
f = x**2

#slope between two points with gap "s"
#substitute into rise-over-run formula
slope_f = (f.subs(x, x + s) - f) / ((x + s) - x)

#substitute 2 for x
slope_2 = slope_f.subs(x, 2)

#calculate slope at x =2
#infinitely approach step size _s_ to 0
result = limit(slope_2, s, 0)

print(result)
# Out:
# 4

# %%
# "x" and step size "s"
x, s = symbols('x s')

#declare function
f = x**2

#slope between two points with gap "s"
#substitute into rise-over-run formula
slope_f = (f.subs(x, x + s) - f) / ((x + s) - x)

#calculate slope at x =2
#infinitely approach step size _s_ to 0
result = limit(slope_f, s, 0)

print(result)
# Out:
# 2*x

# %% [markdown]
# Chain Rule

# %% [markdown]
# ![Screenshot 2023-08-06 144318.png](data:image/png;base64,...)

# %%
#Finding the derivative of z with respect to x
from sympy import *

z = (x**2 + 1)**3 -2
dz_dx = diff(z, x)
print(dz_dx)
# Out:
# 6*x*(x**2 + 1)**2

# %% [markdown]
# Comparing with and without chain rule

# %%
from sympy import *

#Declaring variables to be used
x, y = symbols('x y')

#First function
_y = x**2 + 1

#Second function
z = y**3 -2

dz_dx_chain = diff(_y, x) * diff(z, y).subs(y, _y)
dz_dx_no_chain = diff(z.subs(y, _y))


print(dz_dx_chain)
print(dz_dx_no_chain)
# Out:
# 6*x*(x**2 + 1)**2
# 6*x*(x**2 + 1)**2

# %% [markdown]
# Integrals

# %% [markdown]
# ![Screenshot 2023-08-06 160525.png](data:image/png;base64,...)

# %%
#Integral Approximation
def approximate_integral(a, b, n, f):
  delta_x = (b - a) / n
  total_sum = 0

  for i in range(1, n + 1):
    midpoint = 0.5 * (2 * a + delta_x * (2 * i - 1))
    total_sum += f(midpoint)

  return total_sum * delta_x

def my_function(x):
  return x**2 + 1

area = approximate_integral(a=0, b=1, n=5, f=my_function)

print(area)
# Out:
# 1.33

# %%
area = approximate_integral(a=0, b=1, n=1000, f=my_function)

print(area)
# Out:
# 1.333333250000001

# %%
#Using SymPy to perform integration
from sympy import *

#Declare 'x' to SymPy
x = symbols('x')

#Declare function
f = x**2 + 1

#Calculate the integral function with respect to x
#for the area betweenb x = 0 and 1
area = integrate(f, (x, 0, 1))

print(area)
# Out:
# 4/3

# %% [markdown]
# Calculating Integrals with Limits

# %%
#Using limits to calculate integrals

from sympy import *

#Declare variables to SymPy
x, i, n = symbols('x i n')

#Declare function and range
f = x**2 + 1
lower, upper = 0, 1

#Calculate width and each rectangle height at index "i"
delta_x = ((upper - lower) / n)
x_i = (lower + delta_x * i)
fx_i = f.subs(x, x_i)

#Iterate all "n" rectangles and sum their areas
n_rectangles = Sum(delta_x * fx_i, (i, 1, n)).doit()

#Calculate the area by approaching the number of retangles "n" to infinity
area = limit(n_rectangles, n, oo)

print(area)
# Out:
# 4/3

# %% [markdown]
# Exercises
# 1. rational, because the decimal points are terminating
# 2.

# %% [markdown]
# Solutions

# %%
x = (10**7)*(10**-5)
print(x)
# Out:
# 100.00000000000001

# %%
x = 81**(1/2)
print(x)
# Out:
# 9.0

# %%
x = 25**(3/2)
print(x)
# Out:
# 125.0

# %%
from math import exp

p = 1000
r = .05
t = 3
n = 12

a = p * (1 + (r / n))**(n*t)
print(a)
# Out:
# 1161.4722313334678

# %%
from math import exp

p = 1000
r = .05
t = 3.0

a = p * exp(r * t)
print(a)
# Out:
# 1161.834242728283

# %%
from sympy import *

# "x" and step size "s"
x, s = symbols('x s')

#declare function
f = (3*x**2) + 1

#slope between two points with gap "s"
#substitute into rise-over-run formula
slope_f = (f.subs(x, x + s) - f) / ((x + s) - x)

#substitute 2 for x
slope_2 = slope_f.subs(x, 3)

#calculate slope at x =2
#infinitely approach step size _s_ to 0
result = limit(slope_2, s, 0)

print(result)
# Out:
# 18

# %%
from sympy import *

x = symbols('x')
f = 3*x**2 + 1

print(diff(f).subs(x, 3))
# Out:
# 18

# %%
from sympy import *

x = symbols('x')
f = (3*x**2) + 1

area = integrate(f, (x, 0, 2))
print(area)
# Out:
# 10

# %% [markdown]
# **Chapter 2. Probability**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-08-07 210104.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-08-07 210328.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-11-04 202709.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-11-04 202848.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Using Bayes' Theorem
p_coffee_drinker = .65
p_cancer = 0.05
p_coffee_drinker_given_cancer = .85

p_cancer_given_coffee_drinker = p_coffee_drinker_given_cancer * p_cancer / p_coffee_drinker

print(p_cancer_given_coffee_drinker)
# Out:
# 0.06538461538461539

# %%
#Using scipy for binomial distribution
from scipy.stats import binom

n=10
p=0.9

for k in range(n+1):
    probability=binom.pmf(k, n, p)
    print("{0} - {1}".format(k, probability))
# Out:
# 0 - 9.999999999999978e-11
# 1 - 8.999999999999978e-09
# 2 - 3.6449999999999943e-07
# 3 - 8.747999999999991e-06
# 4 - 0.00013778099999999974
# 5 - 0.0014880347999999982
# 6 - 0.011160260999999996
# 7 - 0.05739562799999997
# 8 - 0.1937102444999998
# 9 - 0.38742048899999976
# 10 - 0.3486784401000001

# %%
#Beta distribution using Scipy
from scipy.stats import beta

a=8
b=2

p=beta.cdf(.90, a, b)

print(p)
# Out:
# 0.7748409780000002

# %%
#Beta distribution with more trials

from scipy.stats import beta

a=30
b=6

p=1.0-beta.cdf(.90, a, b)

print(p)
# Out:
# 0.13163577484183697

# %%
#Beta distribution middle area using SciPy

from scipy.stats import beta

a=8
b=2

p=beta.cdf(.90, a, b)-beta.cdf(.80, a, b)

print(p)
# Out:
# 0.33863336199999994

# %% [markdown]
# Exercises
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Answers:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Mean and Weighted Mean

# %%
#Example 3.1. Calculating mean in Python
#Number of pets each person owns
sample = [1,3,2,5,7,0,2,3]

mean = sum(sample) / len(sample)

print(mean)
# Out:
# 2.875

# %%
#Example 3-2. Calculating a weighted mean in Python
#Three exams of .20 weight each and final exam of .40 weight
sample = [90, 80, 63, 87]
weights = [.20, .20, .20, .40]

weighted_mean = sum(s * w for s,w in zip(sample, weights))
sum(weights)

print(weighted_mean)
# Out:
# 81.4

# %%
#Example 3-3. Calculating a weighted mean in Python
#Three exams of .20 weight each and final exam of .40 weight
sample = [90, 80, 63, 87]
weights = [1.0, 1.0, 1.0, 2.0]

weighted_mean = sum(s * w for s,w in zip(sample, weights))/sum(weights)
sum(weights)

print(weighted_mean)
# Out:
# 81.4

# %%
#Example  3-4. Calculating the median in Python
sample = [0,1,5,7,9,10,14]

def median(values):
  ordered = sorted(values)
  print(ordered)
  n = len(ordered)
  mid = int(n/2)-1 if n% 2 == 0 else int(n/2)

  if n%2 == 0:
    return (ordered[mid]+ordered[mid+1]) / 2.0
  else:
    return ordered[mid]

print(median(sample))
# Out:
# [0, 1, 5, 7, 9, 10, 14]
# 7

# %%
#Example 3-5. Calculating the mode in Python
from collections import defaultdict

sample = [1,3,2,5,7,0,2,3]

def mode(values):
  counts = defaultdict(lambda: 0)

  for s in values:
      counts[s] += 1

  max_count = max(counts.values())
  modes = [v for v in set(values) if counts[v] == max_count]
  return modes

print(mode(sample))
# Out:
# [2, 3]

# %%
#Example 3-6. Calculating variance in Python
#Number of pets each person owns
data = [0,1,5,7,9,10,14]

def variance(values):
  mean = sum(values) / len(values)
  _variance = sum((v - mean) ** 2 for v in values) / len(values)
  return _variance

print(variance(data))
# Out:
# 21.387755102040813

# %%
#Example 3-7. Calculating standard deviation in Python
from math import sqrt

#Number of pets each person owns
data = [0,1,5,7,9,10,14]

def variance(values):
    mean = sum(values) / len(values)
